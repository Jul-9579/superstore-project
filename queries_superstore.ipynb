# %%
import sqlite3
import pandas as pd
import os

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_corporate_customers = """
   SELECT CustomerID, CustomerName, Segment FROM customers WHERE Segment = 'Corporate'
"""

cur.execute(select_corporate_customers)
rows = cur.fetchall()

corporate_df = pd.DataFrame(rows, columns=["CustomerID", "CustomerName", "Segment"])

cur.close()
conn.close()

# %%
corporate_df
# Out:
#     CustomerID     CustomerName    Segment
# 0     DV-13045  Darrin Van Huff  Corporate
# 1     KB-16585        Ken Black  Corporate
# 2     GH-14485        Gene Hale  Corporate
# 3     LC-16930   Linda Cazamias  Corporate
# 4     RA-19885     Ruben Ausman  Corporate
# ..         ...              ...        ...
# 231   TC-21145    Theresa Coyne  Corporate
# 232   CM-12715   Craig Molinari  Corporate
# 233   FW-14395   Fred Wasserman  Corporate
# 234   HE-14800     Harold Engle  Corporate
# 235   CJ-11875     Carl Jackson  Corporate
#
# [236 rows x 3 columns]

# %% [markdown]
# ## What is the category generating the maximum sales revenue?

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_max_sales = """

SELECT p.Category, Sum(o_i.Sales) AS Profit
FROM products p
JOIN order_items o_i ON p.ProductID = o_i.ProductID
GROUP BY p.Category
ORDER BY Profit DESC
LIMIT 1

"""

cur.execute(select_max_sales)
rows = cur.fetchall()

max_sales_df = pd.DataFrame(rows, columns=["Category", "Sales"])

cur.close()
conn.close()

max_sales_df
# Out:
#      Category       Sales
# 0  Technology  836154.033

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_max_sales = """

SELECT p.Category
FROM products p
JOIN order_items o_i ON p.ProductID = o_i.ProductID
ORDER BY o_i.Profit DESC
LIMIT 1

"""

cur.execute(select_max_sales)
rows = cur.fetchall()

max_sales_df = pd.DataFrame(rows, columns=["Category"])

cur.close()
conn.close()

max_sales_df
# Out:
#      Category
# 0  Technology

# %% [markdown]
# ### Profit in the technology category

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_technology_profit = """

SELECT p.Category, sum(o_i.Profit)
FROM products p
JOIN order_items o_i ON p.ProductID = o_i.ProductID
WHERE p.Category = 'Technology'

"""

cur.execute(select_technology_profit)
rows = cur.fetchall()

technology_profit_df = pd.DataFrame(rows, columns=["Category", "Profit"])

cur.close()
conn.close()

technology_profit_df
# Out:
#      Category       Profit
# 0  Technology  145454.9481

# %% [markdown]
# ### Are they making a loss in any categories?

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_technology_subcategory = """

SELECT p.SubCategory, Max(o_i.Sales), o_i.Profit
FROM products p
JOIN order_items o_i ON p.ProductID = o_i.ProductID
WHERE p.Category = 'Technology'
GROUP BY p.SubCategory
"""

cur.execute(select_technology_subcategory)
rows = cur.fetchall()

technology_subcategory_df = pd.DataFrame(rows, columns=["SubCategory", "Sales", "Profit",])

cur.close()
conn.close()

technology_subcategory_df
# Out:
#    SubCategory     Sales     Profit
# 0  Accessories   3347.37   636.0003
# 1      Copiers  17499.95  8399.9760
# 2     Machines  22638.48 -1811.0784
# 3       Phones   4548.81  1228.1787

# %% [markdown]
# ## What are 5 states generating the maximum and minimum sales revenue?

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_state_max_sales = """

SELECT a.State, sum(o_i.Sales) AS Sales
FROM addresses a
JOIN customer_orders co ON a.CustomerID = co.CustomerID
JOIN order_items o_i ON co.OrderID = o_i.OrderID
GROUP BY a.State
ORDER BY o_i.Sales DESC
LIMIT 5


"""

cur.execute(select_state_max_sales)
rows = cur.fetchall()

state_max_sales_df = pd.DataFrame(rows, columns=["State","Sales"])

cur.close()
conn.close()

state_max_sales_df
# Out:
#             State         Sales
# 0      Washington  8.622987e+05
# 1        New York  1.859365e+06
# 2        Colorado  2.546810e+05
# 3   West Virginia  1.140548e+04
# 4  South Carolina  8.610077e+04

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_state_min_sales = """

SELECT a.State, o_i.Sales
FROM addresses a
JOIN customer_orders co ON a.CustomerID = co.CustomerID
JOIN order_items o_i ON co.OrderID = o_i.OrderID
GROUP BY a.State
ORDER BY o_i.Sales ASC
LIMIT 5


"""

cur.execute(select_state_min_sales)
rows = cur.fetchall()

state_min_sales_df = pd.DataFrame(rows, columns=["State","Sales"])

cur.close()
conn.close()

state_min_sales_df
# Out:
#                   State   Sales
# 0               Indiana   8.560
# 1                 Idaho   8.820
# 2  District of Columbia  10.824
# 3            California  14.620
# 4               Florida  14.620

# %% [markdown]
# ## What are the 3 products in each product segment with the highest sales?

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_top3_product = """

WITH ranked_product AS (
    SELECT 
        p.ProductName, 
        p.Category, 
        sum(o_i.Sales),
        RANK() OVER (PARTITION BY p.Category ORDER BY sum(o_i.Sales) DESC) AS sales_rank
    FROM products p
    JOIN order_items o_i ON o_i.ProductID = p.ProductID
    GROUP BY p.ProductName  
)
SELECT *
FROM ranked_product
WHERE sales_rank <= 3


"""

cur.execute(select_top3_product)
rows = cur.fetchall()

top3_product_df = pd.DataFrame(rows, columns=["ProductName", "Category", "Sales", "sales_rank"])

cur.close()
conn.close()

top3_product_df
# Out:
#                                          ProductName         Category  \
# 0       HON 5400 Series Task Chairs for Big and Tall        Furniture
# 1  Riverside Palais Royal Lawyers Bookcase, Royal...        Furniture
# 2         Bretford Rectangular Conference Table Tops        Furniture
# 3  Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 4         GBC DocuBind TL300 Electric Binding System  Office Supplies
# 5   GBC Ibimaster 500 Manual ProClick Binding System  Office Supplies
# 6              Canon imageCLASS 2200 Advanced Copier       Technology
# 7  Cisco TelePresence System EX90 Videoconferenci...       Technology
# 8               Hewlett Packard LaserJet 3310 Copier       Technology
#
#         Sales  sales_rank
# 0  21870.5760           1
# 1  15610.9656           2
# 2  12995.2915           3
# 3  27453.3840           1
# 4  19823.4790           2
# 5  19024.5000           3
# 6  61599.8240           1
# 7  22638.4800           2
# 8  18839.6860           3

# %% [markdown]
# ### Are they the 3 most profitable products as well?

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_top3_profit = """

WITH ranked_product AS (
    SELECT 
        p.ProductName, 
        p.Category, 
        sum(o_i.Profit),
        RANK() OVER (PARTITION BY p.Category ORDER BY o_i.Profit DESC) AS profit_rank
    FROM products p
    JOIN order_items o_i ON o_i.ProductID = p.ProductID 
    GROUP BY p.ProductName     
)
SELECT *
FROM ranked_product
WHERE profit_rank <= 3


"""

cur.execute(select_top3_profit)
rows = cur.fetchall()

top3_profit_df = pd.DataFrame(rows, columns=["ProductName", "Category", "Profit", "Profit_rank"])


top3_profit_df
# Out:
#                                          ProductName         Category  \
# 0  Office Star - Professional Matrix Back Chair w...        Furniture
# 1  Chromcraft 48" x 96" Racetrack Double Pedestal...        Furniture
# 2                    Global Comet Stacking Arm Chair        Furniture
# 3               Ibico EPK-21 Electric Binding System  Office Supplies
# 4  Fellowes PB500 Electric Punch Plastic Comb Bin...  Office Supplies
# 5          GBC DocuBind P400 Electric Binding System  Office Supplies
# 6              Canon imageCLASS 2200 Advanced Copier       Technology
# 7                  Ativa V4110MDD Micro-Cut Shredder       Technology
# 8   3D Systems Cube Printer, 2nd Generation, Magenta       Technology
#
#        Profit  Profit_rank
# 0   1305.6456            1
# 1   -404.0064            2
# 2    697.1415            3
# 3   3345.2823            1
# 4   7753.0390            2
# 5  -1878.1662            3
# 6  25199.9280            1
# 7   3772.9461            2
# 8   3717.9714            3

# %% [markdown]
# ## What are the 3 best-seller products in each product segment? (Quantity-wise)

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_top3_seller = """

WITH best_seller AS (
    SELECT 
        p.ProductName, 
        p.Category, 
        sum(o_i.Quantity),
        ROW_NUMBER() OVER (PARTITION BY p.Category ORDER BY sum(o_i.Quantity) DESC) AS quantity_rank
    FROM products p
    JOIN order_items o_i ON o_i.ProductID = p.ProductID 
    GROUP BY p.ProductName     
)
SELECT *
FROM best_seller
WHERE quantity_rank <= 3


"""

cur.execute(select_top3_seller)
rows = cur.fetchall()

top3_seller_df = pd.DataFrame(rows, columns=["ProductName", "Category", "Quantity", "Quantity_rank"])


top3_seller_df
# Out:
#                                   ProductName         Category  Quantity  \
# 0                  KI Adjustable-Height Table        Furniture        74
# 1  Situations Contoured Folding Chairs, 4/Set        Furniture        64
# 2                  Staple-based wall hangings        Furniture        62
# 3                                     Staples  Office Supplies       215
# 4                             Staple envelope  Office Supplies       170
# 5                           Easy-staple paper  Office Supplies       150
# 6          Logitech P710e Mobile Speakerphone       Technology        75
# 7   Logitech G19 Programmable Gaming Keyboard       Technology        60
# 8  Kingston Digital DataTraveler 16GB USB 2.0       Technology        57
#
#    Quantity_rank
# 0              1
# 1              2
# 2              3
# 3              1
# 4              2
# 5              3
# 6              1
# 7              2
# 8              3

# %% [markdown]
# ## What are the top 3 worst-selling products in every category? (Quantity-wise)

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

select_flop3_seller = """

WITH best_seller AS (
    SELECT 
        p.ProductName, 
        p.Category, 
        sum(o_i.Quantity),
        ROW_NUMBER() OVER (PARTITION BY p.Category ORDER BY sum(o_i.Quantity) ASC) AS quantity_rank
    FROM products p
    JOIN order_items o_i ON o_i.ProductID = p.ProductID 
    GROUP BY p.ProductName     
)
SELECT *
FROM best_seller
WHERE quantity_rank <= 3


"""

cur = conn.cursor()  # Reopen the cursor
cur.execute(select_flop3_seller)
rows = cur.fetchall()

flop3_seller_df = pd.DataFrame(rows, columns=["ProductName", "Category", "Quantity", "Quantity_rank"])

cur.close()
conn.close()

flop3_seller_df
# Out:
#                                          ProductName         Category  \
# 0  Bush Saratoga Collection 5-Shelf Bookcase, Han...        Furniture
# 1  Global Enterprise Series Seating Low-Back Swiv...        Furniture
# 2  Barricks Non-Folding Utility Table with Steel ...        Furniture
# 3              Boston 1900 Electric Pencil Sharpener  Office Supplies
# 4                                           Xerox 20  Office Supplies
# 5                                            Avery 5  Office Supplies
# 6                Penpower WorldCard Pro Card Scanner       Technology
# 7  Canon imageCLASS MF7460 Monochrome Digital Las...       Technology
# 8  Hewlett-Packard Deskjet F4180 All-in-One Color...       Technology
#
#    Quantity  Quantity_rank
# 0         1              1
# 1         1              2
# 2         2              3
# 3         1              1
# 4         1              2
# 5         2              3
# 6         1              1
# 7         2              2
# 8         2              3

# %% [markdown]
# ## How many unique customers per month are there for the year 2016.

# %% [markdown]
# ### Add year and month columns

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

# Add Year and Month columns to the customer_orders table
cur.execute("ALTER TABLE customer_orders ADD COLUMN Year INTEGER;")
cur.execute("ALTER TABLE customer_orders ADD COLUMN Month INTEGER;")

# Update the Year and Month columns based on the OrderDate
cur.execute("""
UPDATE customer_orders
SET
    Year = CAST(strftime('%Y', OrderDate) AS INTEGER),
    Month = CAST(strftime('%m', OrderDate) AS INTEGER);
""")


# Select the updated data
cur.execute("SELECT OrderDate, Year, Month FROM customer_orders")
rows = cur.fetchall()

# Create a DataFrame from the result
year_month_df = pd.DataFrame(rows, columns=["OrderDate", "Year", "Month"])

cur.close()
conn.close()

year_month_df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[33], line 5
#       2 cur = conn.cursor()
#       4 # Add Year and Month columns to the customer_orders table
# ----> 5 cur.execute("ALTER TABLE customer_orders ADD COLUMN Year INTEGER;")
#       6 cur.execute("ALTER TABLE customer_orders ADD COLUMN Month INTEGER;")
#       8 # Update the Year and Month columns based on the OrderDate
#
# OperationalError: duplicate column name: Year

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

# Update the Year and Month columns based on the OrderDate
cur.execute("""
UPDATE customer_orders
SET
    Year = CAST(strftime('%Y', OrderDate) AS INTEGER),
    Month = CAST(strftime('%m', OrderDate) AS INTEGER);
""")

# Commit the changes
conn.commit()

# Select the updated data
cur.execute("SELECT OrderDate, Year, Month FROM customer_orders")
rows = cur.fetchall()

# Create a DataFrame from the result
year_month_df = pd.DataFrame(rows, columns=["OrderDate", "Year", "Month"])

cur.close()
conn.close()

year_month_df
# Out:
#        OrderDate  Year  Month
# 0     2016-11-08  2016     11
# 1     2016-06-12  2016      6
# 2     2015-10-11  2015     10
# 3     2014-06-09  2014      6
# 4     2017-04-15  2017      4
# ...          ...   ...    ...
# 5004  2016-09-29  2016      9
# 5005  2017-11-17  2017     11
# 5006  2014-01-21  2014      1
# 5007  2017-02-26  2017      2
# 5008  2017-05-04  2017      5
#
# [5009 rows x 3 columns]

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

# Update the Year and Month columns based on the OrderDate
cur.execute("""
SELECT count(DISTINCT customerID) as Customer_Count, Year, Month
FROM customer_orders
WHERE Year = 2016
GROUP BY Month
""")

# Fetch the results of the query
rows = cur.fetchall()

# Create a DataFrame from the result
customers_2016_df = pd.DataFrame(rows, columns=["Customer_Count", "Year", "Month"])

cur.close()
conn.close()

customers_2016_df
# Out:
#     Customer_Count  Year  Month
# 0               46  2016      1
# 1               42  2016      2
# 2               80  2016      3
# 3               83  2016      4
# 4               96  2016      5
# 5               90  2016      6
# 6               89  2016      7
# 7               86  2016      8
# 8              176  2016      9
# 9               95  2016     10
# 10             165  2016     11
# 11             157  2016     12

# %% [markdown]
# ### Join all

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

join_all = """
    SELECT 
        c.CustomerName,
        c.CustomerID,
        c.Segment,

        a.City,
        a.State,
        a.Region,
        a.Country,
        a.PostalCode,

        co.OrderID,
        co.OrderDate,
    
        s.ShipDate,
        s.ShipMode,

        oi.OrderID,
        oi.Sales,  
        oi.Discount,
        oi.Profit,     
        oi.Quantity,

        p.ProductName,
        p.Category,
        p.SubCategory

    FROM customer_orders co
    JOIN customers c ON co.CustomerID = c.CustomerID
    JOIN shipments s ON co.OrderID = s.OrderID
    JOIN addresses a ON s.AddressID = a.AddressID
    JOIN order_items oi ON co.OrderID = oi.OrderID
    JOIN products p ON oi.ProductID = p.ProductID
      """

cur.execute(join_all)
join_all_result = pd.DataFrame(cur.fetchall(), columns=["CustomerName", "CustomerID", "Segment", "City", "State",
                                                        "Region", "Country", "PostalCode", "OrderID", "OrderDate",
                                                        "ShipMode", "ShipDate", "Category", "SubCategory", "ProductID",
                                                        "ProductName", "Sales", "Discount", "Profit", "Quantity"])
join_all_result.to_csv("sqlized_superstore.csv", index=False)

# %% [markdown]
# #### Corrected Code (correct order)

# %%
conn = sqlite3.connect("superstore.db")
cur = conn.cursor()

join_all = """
    SELECT 
        c.CustomerName,
        c.CustomerID,
        c.Segment,

        a.City,
        a.State,
        a.Region,
        a.Country,
        a.PostalCode,

        co.OrderID,
        co.OrderDate,
    
        s.ShipDate,
        s.ShipMode,

        oi.Sales,  
        oi.Discount,
        oi.Profit,     
        oi.Quantity,

        p.ProductName,
        p.Category,
        p.SubCategory

    FROM customer_orders co
    JOIN customers c ON co.CustomerID = c.CustomerID
    JOIN shipments s ON co.OrderID = s.OrderID
    JOIN addresses a ON s.AddressID = a.AddressID
    JOIN order_items oi ON co.OrderID = oi.OrderID
    JOIN products p ON oi.ProductID = p.ProductID
"""

cur.execute(join_all)

join_all_result = pd.DataFrame(cur.fetchall(), columns=[
    "CustomerName", "CustomerID", "Segment",
    "City", "State", "Region", "Country", "PostalCode",
    "OrderID", "OrderDate",
    "ShipDate", "ShipMode",
    "Sales", "Discount", "Profit", "Quantity",
    "ProductName", "Category", "SubCategory"
])

join_all_result.to_csv("sqlized_superstore.csv", index=False, decimal=",")

# %%
df_from_csv = pd.read_csv("sqlized_superstore.csv")
print(df_from_csv)
# Out:
#           CustomerName CustomerID    Segment             City       State  \
# 0          Claire Gute   CG-12520   Consumer        Henderson    Kentucky
# 1          Claire Gute   CG-12520   Consumer        Henderson    Kentucky
# 2      Darrin Van Huff   DV-13045  Corporate      Los Angeles  California
# 3       Sean O'Donnell   SO-20335   Consumer  Fort Lauderdale     Florida
# 4       Sean O'Donnell   SO-20335   Consumer  Fort Lauderdale     Florida
# ...                ...        ...        ...              ...         ...
# 9989  Tom Boeckenhauer   TB-21400   Consumer            Miami     Florida
# 9990       Dave Brooks   DB-13060   Consumer       Costa Mesa  California
# 9991       Dave Brooks   DB-13060   Consumer       Costa Mesa  California
# 9992       Dave Brooks   DB-13060   Consumer       Costa Mesa  California
# 9993      Chris Cortes   CC-12220   Consumer      Westminster  California
#
#      Region        Country  PostalCode         OrderID   OrderDate  \
# 0     South  United States       42420  CA-2016-152156  2016-11-08
# 1     South  United States       42420  CA-2016-152156  2016-11-08
# 2      West  United States       90036  CA-2016-138688  2016-06-12
# 3     South  United States       33311  US-2015-108966  2015-10-11
# 4     South  United States       33311  US-2015-108966  2015-10-11
# ...     ...            ...         ...             ...         ...
# 9989  South  United States       33180  CA-2014-110422  2014-01-21
# 9990   West  United States       92627  CA-2017-121258  2017-02-26
# 9991   West  United States       92627  CA-2017-121258  2017-02-26
# 9992   West  United States       92627  CA-2017-121258  2017-02-26
# 9993   West  United States       92683  CA-2017-119914  2017-05-04
#
#         ShipDate        ShipMode     Sales Discount    Profit  Quantity  \
# 0     2016-11-11    Second Class    261,96      0,0   41,9136         2
# 1     2016-11-11    Second Class    731,94      0,0   219,582         3
# 2     2016-06-16    Second Class     14,62      0,0    6,8714         2
# 3     2015-10-18  Standard Class  957,5775     0,45  -383,031         5
# 4     2015-10-18  Standard Class    22,368      0,2    2,5164         2
# ...          ...             ...       ...      ...       ...       ...
# 9989  2014-01-23    Second Class    25,248      0,2    4,1028         3
# 9990  2017-03-03  Standard Class     91,96      0,0   15,6332         2
# 9991  2017-03-03  Standard Class   258,576      0,2   19,3932         2
# 9992  2017-03-03  Standard Class      29,6      0,0     13,32         4
# 9993  2017-05-09    Second Class    243,16      0,0    72,948         2
#
#                                             ProductName         Category  \
# 0                     Bush Somerset Collection Bookcase        Furniture
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...        Furniture
# 2     Self-Adhesive Address Labels for Typewriters b...  Office Supplies
# 3         Bretford CR4500 Series Slim Rectangular Table        Furniture
# 4                        Eldon Fold 'N Roll Cart System  Office Supplies
# ...                                                 ...              ...
# 9989                             Ultra Door Pull Handle        Furniture
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...        Furniture
# 9991                              Aastra 57i VoIP phone       Technology
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"  Office Supplies
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  Office Supplies
#
#       SubCategory
# 0       Bookcases
# 1          Chairs
# 2          Labels
# 3          Tables
# 4         Storage
# ...           ...
# 9989  Furnishings
# 9990  Furnishings
# 9991       Phones
# 9992        Paper
# 9993   Appliances
#
# [9994 rows x 19 columns]

# %%
df_from_csv.head()
# Out:
#       CustomerName CustomerID    Segment             City       State Region  \
# 0      Claire Gute   CG-12520   Consumer        Henderson    Kentucky  South
# 1      Claire Gute   CG-12520   Consumer        Henderson    Kentucky  South
# 2  Darrin Van Huff   DV-13045  Corporate      Los Angeles  California   West
# 3   Sean O'Donnell   SO-20335   Consumer  Fort Lauderdale     Florida  South
# 4   Sean O'Donnell   SO-20335   Consumer  Fort Lauderdale     Florida  South
#
#          Country  PostalCode         OrderID   OrderDate    ShipDate  \
# 0  United States       42420  CA-2016-152156  2016-11-08  2016-11-11
# 1  United States       42420  CA-2016-152156  2016-11-08  2016-11-11
# 2  United States       90036  CA-2016-138688  2016-06-12  2016-06-16
# 3  United States       33311  US-2015-108966  2015-10-11  2015-10-18
# 4  United States       33311  US-2015-108966  2015-10-11  2015-10-18
#
#          ShipMode     Sales Discount    Profit  Quantity  \
# 0    Second Class    261,96      0,0   41,9136         2
# 1    Second Class    731,94      0,0   219,582         3
# 2    Second Class     14,62      0,0    6,8714         2
# 3  Standard Class  957,5775     0,45  -383,031         5
# 4  Standard Class    22,368      0,2    2,5164         2
#
#                                          ProductName         Category  \
# 0                  Bush Somerset Collection Bookcase        Furniture
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...        Furniture
# 2  Self-Adhesive Address Labels for Typewriters b...  Office Supplies
# 3      Bretford CR4500 Series Slim Rectangular Table        Furniture
# 4                     Eldon Fold 'N Roll Cart System  Office Supplies
#
#   SubCategory
# 0   Bookcases
# 1      Chairs
# 2      Labels
# 3      Tables
# 4     Storage
